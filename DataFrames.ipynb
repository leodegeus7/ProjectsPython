# %%
import pandas as pd
import os
print(os.getcwd());
# Out:
# /Users/leodegeus/projectsPythonGH

# %%
stats = pd.read_csv('/Users/leodegeus/projectsPythonGH/tmdb_5000_movies.csv')

# %%
stats[100:110]
# Out:
#         budget                                             genres  \
# 100  150000000  [{"id": 14, "name": "Fantasy"}, {"id": 18, "na...
# 101  160000000  [{"id": 28, "name": "Action"}, {"id": 878, "na...
# 102  160000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 103  150000000  [{"id": 14, "name": "Fantasy"}, {"id": 12, "na...
# 104  160000000  [{"id": 12, "name": "Adventure"}, {"id": 28, "...
# 105  170000000                    [{"id": 14, "name": "Fantasy"}]
# 106  160000000  [{"id": 14, "name": "Fantasy"}, {"id": 12, "na...
# 107  160000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 108  155000000  [{"id": 878, "name": "Science Fiction"}, {"id"...
# 109  155000000  [{"id": 12, "name": "Adventure"}, {"id": 10751...
#
#                                               homepage      id  \
# 100                     http://www.benjaminbutton.com/    4922
# 101               http://www.x-menfirstclassmovie.com/   49538
# ...

# %%
stats[:]
# Out:
#          budget                                             genres  \
# 0     237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1     300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2     245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3     250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4     260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 5     258000000  [{"id": 14, "name": "Fantasy"}, {"id": 28, "na...
# 6     260000000  [{"id": 16, "name": "Animation"}, {"id": 10751...
# 7     280000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 8     250000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 9     250000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 10    270000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 11    200000000  [{"id": 12, "name": "Adventure"}, {"id": 28, "...
# 12    200000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# ...

# %%
stats[185:]
# Out:
#          budget                                             genres  \
# 185   132000000  [{"id": 12, "name": "Adventure"}, {"id": 53, "...
# 186   130000000  [{"id": 12, "name": "Adventure"}, {"id": 28, "...
# 187   130000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 188   110000000  [{"id": 28, "name": "Action"}, {"id": 9648, "n...
# 189   125000000  [{"id": 18, "name": "Drama"}, {"id": 12, "name...
# 190   130000000  [{"id": 12, "name": "Adventure"}, {"id": 16, "...
# 191   130000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 192   130000000                      [{"id": 18, "name": "Drama"}]
# 193   130000000  [{"id": 878, "name": "Science Fiction"}, {"id"...
# 194   127500000  [{"id": 16, "name": "Animation"}, {"id": 10751...
# 195   127000000  [{"id": 12, "name": "Adventure"}, {"id": 35, "...
# 196   130000000  [{"id": 16, "name": "Animation"}, {"id": 28, "...
# 197   125000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# ...

# %%
stats.head(10)
# Out:
#       budget                                             genres  \
# 0  237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1  300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2  245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3  250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4  260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 5  258000000  [{"id": 14, "name": "Fantasy"}, {"id": 28, "na...
# 6  260000000  [{"id": 16, "name": "Animation"}, {"id": 10751...
# 7  280000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 8  250000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 9  250000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#
#                                             homepage      id  \
# 0                        http://www.avatarmovie.com/   19995
# 1       http://disney.go.com/disneypictures/pirates/     285
# 2        http://www.sonypictures.com/movies/spectre/  206647
# ...

# %%
stats[::-1]
# Out:
#          budget                                             genres  \
# 4802          0                [{"id": 99, "name": "Documentary"}]
# 4801          0                                                 []
# 4800          0  [{"id": 35, "name": "Comedy"}, {"id": 18, "nam...
# 4799       9000  [{"id": 35, "name": "Comedy"}, {"id": 10749, "...
# 4798     220000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4797          0  [{"id": 10769, "name": "Foreign"}, {"id": 53, ...
# 4796       7000  [{"id": 878, "name": "Science Fiction"}, {"id"...
# 4795          0                      [{"id": 18, "name": "Drama"}]
# 4794          0  [{"id": 53, "name": "Thriller"}, {"id": 27, "n...
# 4793          0                      [{"id": 18, "name": "Drama"}]
# 4792      20000  [{"id": 80, "name": "Crime"}, {"id": 27, "name...
# 4791         13                     [{"id": 27, "name": "Horror"}]
# 4790          0  [{"id": 18, "name": "Drama"}, {"id": 10769, "n...
# ...

# %%
stats['original_language'].head()
# Out:
# 0    en
# 1    en
# 2    en
# 3    en
# 4    en
# Name: original_language, dtype: object

# %%
stats['original_language'][1:3][1]
# Out:
# 'en'

# %%
#Basic Operation

# %%
results = stats.runtime * stats.vote_average
results.head()
# Out:
# 0    1166.4
# 1    1166.1
# 2     932.4
# 3    1254.0
# 4     805.2
# dtype: float64

# %%
stats['Multiplication'] = results

# %%
stats.drop('Multiplication',1).head()
# Out:
#       budget                                             genres  \
# 0  237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1  300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2  245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3  250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4  260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#
#                                        homepage      id  \
# 0                   http://www.avatarmovie.com/   19995
# 1  http://disney.go.com/disneypictures/pirates/     285
# 2   http://www.sonypictures.com/movies/spectre/  206647
# 3            http://www.thedarkknightrises.com/   49026
# 4          http://movies.disney.com/john-carter   49529
#
#                                             keywords original_language  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...                en
# 1  [{"id": 270, "name": "ocean"}, {"id": 726, "na...                en
# ...

# %%
Filter = stats[['genres','runtime']][1:5].runtime > 148
Filter
# Out:
# 1     True
# 2    False
# 3     True
# 4    False
# Name: runtime, dtype: bool

# %%
stats[1:5][Filter]
# Out:
#       budget                                             genres  \
# 1  300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 3  250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
#
#                                        homepage     id  \
# 1  http://disney.go.com/disneypictures/pirates/    285
# 3            http://www.thedarkknightrises.com/  49026
#
#                                             keywords original_language  \
# 1  [{"id": 270, "name": "ocean"}, {"id": 726, "na...                en
# 3  [{"id": 849, "name": "dc comics"}, {"id": 853,...                en
#
#                              original_title  \
# 1  Pirates of the Caribbean: At World's End
# 3                     The Dark Knight Rises
#
#                                             overview  popularity  \
# 1  Captain Barbossa, long believed to be dead, ha...  139.082615
# 3  Following the death of District Attorney Harve...  112.312950
#
# ...

# %%
novo = stats[1:5][Filter]
novo[novo.budget == 300000000]
# Out:
#       budget                                             genres  \
# 1  300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
#
#                                        homepage   id  \
# 1  http://disney.go.com/disneypictures/pirates/  285
#
#                                             keywords original_language  \
# 1  [{"id": 270, "name": "ocean"}, {"id": 726, "na...                en
#
#                              original_title  \
# 1  Pirates of the Caribbean: At World's End
#
#                                             overview  popularity  \
# 1  Captain Barbossa, long believed to be dead, ha...  139.082615
#
#                                 production_companies       ...        \
# 1  [{"name": "Walt Disney Pictures", "id": 2}, {"...       ...
#
#   release_date    revenue  runtime                          spoken_languages  \
# 1   2007-05-19  961000000    169.0  [{"iso_639_1": "en", "name": "English"}]
#
# ...

# %%
stats.original_language
# Out:
# 0       en
# 1       en
# 2       en
# 3       en
# 4       en
# 5       en
# 6       en
# 7       en
# 8       en
# 9       en
# 10      en
# 11      en
# 12      en
# 13      en
# 14      en
# 15      en
# 16      en
# 17      en
# 18      en
# 19      en
# 20      en
# 21      en
# 22      en
# 23      en
# 24      en
# 25      en
# 26      en
# 27      en
# 28      en
# 29      en
#         ..
# 4773    en
# 4774    en
# 4775    en
# 4776    en
# 4777    en
# 4778    en
# 4779    en
# 4780    en
# 4781    en
# 4782    en
# 4783    en
# 4784    en
# 4785    en
# 4786    en
# 4787    en
# 4788    en
# 4789    en
# 4790    fa
# 4791    en
# 4792    ja
# 4793    en
# 4794    en
# 4795    en
# 4796    en
# 4797    en
# 4798    es
# 4799    en
# 4800    en
# 4801    en
# 4802    en
# Name: original_language, Length: 4803, dtype: object

# %%
stats.iat[2,2]
# Out:
# 'http://www.sonypictures.com/movies/spectre/'

# %%
stats.at[2,'homepage']
# Out:
# 'http://www.sonypictures.com/movies/spectre/'

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import warnings as warnings
warnings.filterwarnings('ignore')

# %%
sns.distplot(stats['vote_average'])

# %%
bis = sns.boxplot(data=stats,x='vote_average',y='popularity',fliersize=1,whis=0.2)
bis

# %%
new = stats[stats.popularity > 200]
vis3 = sns.lmplot(data=new,x='vote_average',y='popularity',hue='original_language',fit_reg=False,size=15)

# %%
stats.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4803 entries, 0 to 4802
# Data columns (total 21 columns):
# budget                  4803 non-null int64
# genres                  4803 non-null object
# homepage                1712 non-null object
# id                      4803 non-null int64
# keywords                4803 non-null object
# original_language       4803 non-null object
# original_title          4803 non-null object
# overview                4800 non-null object
# popularity              4803 non-null float64
# production_companies    4803 non-null object
# production_countries    4803 non-null object
# release_date            4802 non-null object
# revenue                 4803 non-null int64
# runtime                 4801 non-null float64
# spoken_languages        4803 non-null object
# status                  4803 non-null object
# tagline                 3959 non-null object
# title                   4803 non-null object
# ...

# %%
stats[40]
